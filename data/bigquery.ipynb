# %%
import pandas as pd
from google.cloud import bigquery

# %load_ext google.cloud.bigquery
# for large datasets store data in google storage for improved speed using the following command
# %bigquery --project job-listings-366015 --use_bqstorage_api

# %%
# %%bigquery tables
# SELECT
# 	*
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.INFORMATION_SCHEMA.COLUMNS
# WHERE
# 	table_name = 'gsearch_jobs_fact'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
tables
# Out:
#           table_catalog                table_schema         table_name  \
# 0   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 1   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 2   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 3   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 4   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 5   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 6   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 7   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 8   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 9   job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 10  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 11  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 12  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 13  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 14  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 15  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 16  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 17  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 18  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 19  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 20  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 21  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 22  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 23  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
# 24  job-listings-366015  gsearch_job_listings_clean  gsearch_jobs_fact
#
#                         column_name  ordinal_position is_nullable  \
# 0                            job_id                 1         YES
# 1                         job_title                 2         YES
# 2                      company_name                 3         YES
# 3                      job_location                 4         YES
# 4                           job_via                 5         YES
# 5                   job_description                 6         YES
# 6     job_highlights_qualifications                 7         YES
# 7   job_highlights_responsibilities                 8         YES
# 8           job_highlights_benefits                 9         YES
# 9                     job_posted_at                10         YES
# 10                       job_salary                11         YES
# 11                job_schedule_type                12         YES
# 12               job_work_from_home                13         YES
# 13                 job_commute_time                14         YES
# 14                   job_extensions                15          NO
# 15                     company_link                16         YES
# 16              company_link_google                17         YES
# 17                company_thumbnail                18         YES
# 18                            error                19         YES
# 19                      search_term                20         YES
# 20                  search_location                21         YES
# 21                      search_time                22         YES
# 22                        search_id                23         YES
# 23            job_no_degree_mention                24         YES
# 24             job_health_insurance                25         YES
#
#         data_type is_generated generation_expression is_stored is_hidden  \
# 0          STRING        NEVER                  None      None        NO
# 1          STRING        NEVER                  None      None        NO
# 2          STRING        NEVER                  None      None        NO
# 3          STRING        NEVER                  None      None        NO
# 4          STRING        NEVER                  None      None        NO
# 5          STRING        NEVER                  None      None        NO
# 6            JSON        NEVER                  None      None        NO
# 7            JSON        NEVER                  None      None        NO
# 8            JSON        NEVER                  None      None        NO
# 9          STRING        NEVER                  None      None        NO
# 10         STRING        NEVER                  None      None        NO
# 11         STRING        NEVER                  None      None        NO
# 12           BOOL        NEVER                  None      None        NO
# 13         STRING        NEVER                  None      None        NO
# 14  ARRAY<STRING>        NEVER                  None      None        NO
# 15         STRING        NEVER                  None      None        NO
# 16         STRING        NEVER                  None      None        NO
# 17         STRING        NEVER                  None      None        NO
# 18           BOOL        NEVER                  None      None        NO
# 19         STRING        NEVER                  None      None        NO
# 20         STRING        NEVER                  None      None        NO
# 21       DATETIME        NEVER                  None      None        NO
# 22         STRING        NEVER                  None      None        NO
# 23           BOOL        NEVER                  None      None        NO
# 24           BOOL        NEVER                  None      None        NO
#
#    is_updatable is_system_defined is_partitioning_column  \
# 0          None                NO                     NO
# 1          None                NO                     NO
# 2          None                NO                     NO
# 3          None                NO                     NO
# 4          None                NO                     NO
# 5          None                NO                     NO
# 6          None                NO                     NO
# 7          None                NO                     NO
# 8          None                NO                     NO
# 9          None                NO                     NO
# 10         None                NO                     NO
# 11         None                NO                     NO
# 12         None                NO                     NO
# 13         None                NO                     NO
# 14         None                NO                     NO
# 15         None                NO                     NO
# 16         None                NO                     NO
# 17         None                NO                     NO
# 18         None                NO                     NO
# 19         None                NO                     NO
# 20         None                NO                     NO
# 21         None                NO                     NO
# 22         None                NO                     NO
# 23         None                NO                     NO
# 24         None                NO                     NO
#
#     clustering_ordinal_position collation_name column_default rounding_mode
# 0                          <NA>           NULL           NULL          None
# 1                          <NA>           NULL           NULL          None
# 2                          <NA>           NULL           NULL          None
# 3                          <NA>           NULL           NULL          None
# 4                          <NA>           NULL           NULL          None
# 5                          <NA>           NULL           NULL          None
# 6                          <NA>           NULL           NULL          None
# 7                          <NA>           NULL           NULL          None
# 8                          <NA>           NULL           NULL          None
# 9                          <NA>           NULL           NULL          None
# 10                         <NA>           NULL           NULL          None
# 11                         <NA>           NULL           NULL          None
# 12                         <NA>           NULL           NULL          None
# 13                         <NA>           NULL           NULL          None
# 14                         <NA>           NULL           NULL          None
# 15                         <NA>           NULL           NULL          None
# 16                         <NA>           NULL           NULL          None
# 17                         <NA>           NULL           NULL          None
# 18                         <NA>           NULL           NULL          None
# 19                         <NA>           NULL           NULL          None
# 20                         <NA>           NULL           NULL          None
# 21                         <NA>           NULL           NULL          None
# 22                         <NA>           NULL           NULL          None
# 23                         <NA>           NULL           NULL          None
# 24                         <NA>           NULL           NULL          None

# %%
# %%bigquery
# SELECT
# 	* EXCEPT (job_highlights_qualifications, job_highlights_responsibilities, job_highlights_benefits)
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# LIMIT 10
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 888.06query/s]
# Downloading: 100%|██████████| 10/10 [00:31<00:00,  3.13s/rows]
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEaXJlY3RvciBEYXRhIGFuZCBBbm...
# 1  eyJqb2JfdGl0bGUiOiJJbnRlcm5zaGlwIERhdGEgRW5naW...
# 2  eyJqb2JfdGl0bGUiOiJEYXRhIEVuZ2luZWVyIiwiaHRpZG...
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIEVuZ2luZWVyIGV4cCB3aX...
# 4  eyJqb2JfdGl0bGUiOiJTZW5pb3IgQ2xpbmljYWwgSW5mb3...
# 5  eyJqb2JfdGl0bGUiOiJTci4gRGF0YSBFbmdpbmVlci9Bcm...
# 6  eyJqb2JfdGl0bGUiOiJTZW5pb3IgRGF0YSBBbmFseXN0IC...
# 7  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 8  eyJqb2JfdGl0bGUiOiJDaWVudGlzdGEgZGUgRGFkb3MiLC...
# 9  eyJqb2JfdGl0bGUiOiJEYXRhIEVuZ2luZWVyIC0gU8Ojby...
#
#                                            job_title  \
# 0            Director Data and Analytics Engineering
# 1                           Internship Data Engineer
# 2                                      Data Engineer
# 3  Data Engineer exp withAWS; ETL; GLUE; java; Or...
# 4          Senior Clinical Informatics Data Engineer
# 5                        Sr. Data Engineer/Architect
# 6                   Senior Data Analyst - Now Hiring
# 7                                       Data Analyst
# 8                                 Cientista de Dados
# 9                     Data Engineer - São Paulo - SP
#
#                   company_name                           job_location  \
# 0                     Discover                    U.S. Virgin Islands
# 1                     Data Max                        Tirana, Albania
# 2      Oxford Global Resources                             Austin, TX
# 3                         Dice                               Anywhere
# 4                   The Lancet                                 Alaska
# 5               APN Consulting                           New York, NY
# 6   Porsche Cars North America                            Atlanta, GA
# 7  R Systems Singapore Pte Ltd                               Malaysia
# 8                        TOTVS                                 Brazil
# 9                      Hunt RH  São Paulo, State of São Paulo, Brazil
#
#                 job_via                                    job_description  \
# 0             via Nexxt  Director Data and Analytics Engineering Remote...
# 1  via LinkedIn Albania  About Data Max\n\nData Max helps companies bec...
# 2          via LinkedIn  Job Title: Data Engineer\n\nLocation: Austin, ...
# 3          via LinkedIn  Dice is the leading career destination for tec...
# 4          via Mendeley  • *Description**\n\nA Senior Clinical Informat...
# 5     via CareerBuilder  Direct Client Requirement\n\nPosition: Sr. Dat...
# 6          via Snagajob  Tasks\n\nPosition Objective...\n\nWe are looki...
# 7    via BeBee Malaysia  JD Job Requirement/Experience/Skillset:\n• An ...
# 8             via BeBee  Descrição :\n\nO QUE VOCÊ VAI FAZER:\n• Dialog...
# 9       via SimplyHired  Estamos atendendo Industria multinacional de g...
#
#   job_posted_at job_salary job_schedule_type  job_work_from_home  ...  \
# 0  10 hours ago       None         Full-time                <NA>  ...
# 1   8 hours ago       None        Internship                <NA>  ...
# 2   2 hours ago       None        Contractor                <NA>  ...
# 3  19 hours ago       None        Contractor                True  ...
# 4  16 hours ago       None         Full-time                <NA>  ...
# 5  17 hours ago       None         Full-time                <NA>  ...
# 6   9 hours ago       None         Full-time                <NA>  ...
# 7  13 hours ago       None         Full-time                <NA>  ...
# 8  16 hours ago       None         Full-time                <NA>  ...
# 9  20 hours ago       None         Full-time                <NA>  ...
#
#                  company_link  \
# 0    http://www.discover.com/
# 1                        None
# 2  http://www.oxfordcorp.com/
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8       http://www.totvs.com/
# 9                        None
#
#                                  company_link_google  \
# 0  https://www.google.com/search?ucbcb=1&hl=en&gl...
# 1  https://www.google.com/search?hl=en&gl=us&q=Da...
# 2  https://www.google.com/search?q=Oxford+Global+...
# 3  https://www.google.com/search?hl=en&gl=us&q=Di...
# 4  https://www.google.com/search?q=The+Lancet&sa=...
# 5  https://www.google.com/search?hl=en&gl=us&q=AP...
# 6  https://www.google.com/search?hl=en&gl=us&q=Po...
# 7  https://www.google.com/search?gl=us&hl=en&q=R+...
# 8  https://www.google.com/search?gl=us&hl=en&q=TO...
# 9  https://www.google.com/search?ucbcb=1&hl=en&gl...
#
#                                    company_thumbnail  error     search_term  \
# 0                                               None  False  Data Scientist
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...  False   Data Engineer
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...  False   Data Engineer
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...  False   Data Engineer
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...  False   Data Engineer
# 5                                               None  False   Data Engineer
# 6                                               None  False    Data Analyst
# 7                                               None  False    Data Analyst
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...  False  Data Scientist
# 9                                               None  False   Data Engineer
#
#        search_location         search_time                 search_id  \
# 0  U.S. Virgin Islands 2023-01-27 06:56:44  63d375ac33b236dab0b7794d
# 1              Albania 2023-01-26 08:00:43  63d2332b8b7ed283c6b03e8f
# 2                Sudan 2023-01-04 16:29:44  63b5a9780a90c7773e5d0871
# 3                Sudan 2023-01-04 16:29:48  63b5a97cd5b1c551cda22da3
# 4                Sudan 2023-01-04 16:29:52  63b5a98095bf922966b14fd7
# 5                Sudan 2023-01-04 16:30:09  63b5a991aef2648b6e57d43e
# 6              Georgia 2023-01-04 16:34:33  63b5aa99c640d2100816e16a
# 7             Malaysia 2023-01-28 07:02:19  63d4c87b033e947cf4b40dd4
# 8               Brazil 2023-01-28 07:03:56  63d4c8dc9c449d5ef751a9c0
# 9               Brazil 2023-01-28 07:04:00  63d4c8e0a4be101b0c2c3f94
#
#   job_no_degree_mention job_health_insurance
# 0                  <NA>                 <NA>
# 1                  <NA>                 <NA>
# 2                  <NA>                 <NA>
# 3                  True                 <NA>
# 4                  <NA>                 True
# 5                  <NA>                 <NA>
# 6                  <NA>                 <NA>
# 7                  <NA>                 <NA>
# 8                  <NA>                 <NA>
# 9                  <NA>                 <NA>
#
# [10 rows x 22 columns]

# %%
# %%bigquery
# -- Job posting websites
# SELECT
# 	job_via AS job_website,
# 	COUNT(job_via) AS job_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# GROUP BY
# 	job_via
# ORDER BY
# 	job_count DESC
# Out:
# UsageError: %%bigquery is a cell magic, but the cell body is empty.

# %%
# %%bigquery
# -- Top job titles
# SELECT
# 	job_title,
# 	COUNT(job_title) AS job_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# GROUP BY
# 	job_title
# ORDER BY
# 	job_count DESC

# %%
# %%bigquery
# -- Degree requirements
# SELECT
# 	search_term,
# 	ROUND(COUNT(job_no_degree_mention) * 100 / COUNT(search_term), 1)
#        AS no_degree_percent,
# 	COUNT(job_no_degree_mention) AS no_degree_count,
# 	COUNT(search_term) AS search_count
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# GROUP BY
# 	search_term
# ORDER BY
# 	no_degree_percent DESC

# %%
# %%bigquery
# -- Work from home
# SELECT
# 	search_term,
# 	ROUND(COUNT(job_work_from_home) * 100 / COUNT(search_term),
# 	1) AS wfh_percent,
# 	COUNT(job_work_from_home) AS wfh_count,
# 	COUNT(search_term) AS search_count
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# GROUP BY
# 	search_term
# ORDER BY
# 	wfh_percent DESC

# %%
# %%bigquery
#
# -- Job location
# SELECT
# 	job_location,
# 	COUNT(job_location) AS job_location_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# GROUP BY
# 	job_location
# ORDER BY
# 	job_location_count DESC

# %%
# %%bigquery
#
# -- Job type
# SELECT
# 	a1.job_schedule_type,
# 	ROUND(COUNT(a1.job_schedule_type) * 100 /
#        (
# 	SELECT
# 		COUNT(job_schedule_type)
# 	FROM
# 		`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact), 1) AS job_type_percent,
# 	COUNT(job_schedule_type) AS job_type_count
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS a1
# GROUP BY
# 	job_schedule_type
# ORDER BY
# 	job_type_percent DESC

# %%
# %%bigquery
# -- Skills
# SELECT
# 	job_description,
# 	job_salary,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# WHERE
# 	job_salary IS NOT NULL
# LIMIT 10

# %%
# %%bigquery
# -- salary table
# SELECT
# 	*
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary
# LIMIT 10
#
# -- average salary
# SELECT
# 	ROUND(AVG(salary_year)) AS avg_annual_salary,
# 	ROUND(AVG(salary_hour), 2) AS avg_hourly_salary,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary

# %%
# %%bigquery
#
# -- average salary per job title
# SELECT
# 	search_term,
# 	ROUND(AVG(salary_year)) AS avg_salary_annual,
# 	-- AVG(salary_hour) AS avg_salary_hourly
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = d.job_id
# GROUP BY
# 	search_term
# ORDER BY
# 	avg_salary_annual DESC

# %%
# %%bigquery
#
# -- range salary
# SELECT
# 	search_term,
# 	MAX(salary_max - salary_min) AS salary_range,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = d.job_id
# GROUP BY
# 	search_term
# ORDER BY
# 	salary_range DESC

# %%
# %%bigquery
#
# -- top salary range inspect
# SELECT
# 	* EXCEPT (job_highlights_qualifications, job_highlights_responsibilities, job_highlights_benefits)
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = d.job_id
# WHERE
# 	(salary_max - salary_min) > 250000

# %%
# %%bigquery salary --project job-listings-366015
#
# -- median salary
# SELECT
# 	search_term,
# 	median_salary_annual,
# 	median_salary_hourly,
# FROM
# 	(
# 	SELECT
# 		search_term,
# 		PERCENTILE_CONT(salary_year, 0.5) OVER (PARTITION BY search_term)
#                  AS median_salary_annual,
# 		PERCENTILE_CONT(salary_hour, 0.5) OVER (PARTITION BY search_term)
#                  AS median_salary_hourly
# 	FROM
# 		`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# 	LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 		f.job_id = d.job_id)
# GROUP BY
# 	search_term,
# 	median_salary_annual,
# 	median_salary_hourly
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 2409.13query/s]
# Downloading: 100%|██████████| 3/3 [00:31<00:00, 10.41s/rows]

# %%
# salary.plot(kind='bar', x='search_term', y='median_salary_annual', figsize=(20, 10))
import altair as alt
# make altair bar chart
# order by median salary

df = salary
x = 'median_salary_annual'
y = 'search_term'

selector = alt.selection_single(encodings=['x', 'y'])
alt.Chart(df, height=alt.Step(30) # adjust the spacing of the bars
).mark_bar(
    cornerRadiusBottomRight=5,
    cornerRadiusTopRight=5    
).encode(
    y=alt.Y(y, sort=None, title="", axis=alt.Axis(labelFontSize=20) ), # , labelAngle=-35
    x=alt.X(x, title="Likelyhood to be in Job Posting", axis=alt.Axis(format='$,', labelFontSize=17, titleFontSize=17)),
    color=alt.condition(selector, x, alt.value('lightgray'), legend=None),
    tooltip=[x, alt.Tooltip(x, format=".1%")] 
).add_selection(
    selector
).configure_view(
    strokeWidth=0
).configure_scale(
    bandPaddingInner=0.2 # adjust the width of the bars
)
# Out:
# alt.Chart(...)

# %%
# %%bigquery
#
# -- highest salary
# SELECT
# 	job_title,
# 	job_salary,
# 	job_location,
# 	company_name,
# 	* EXCEPT (job_highlights_qualifications, job_highlights_responsibilities, job_highlights_benefits)
# FROM
# `job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# f.job_id = d.job_id
# WHERE
# salary_avg > 370000 -- WHERE salary_hour > 100
# ORDER BY
# salary_avg DESC

# %%
# %%bigquery
#
# -- lowest salary
# SELECT
# 	job_title,
# 	job_salary,
# 	job_location,
# 	company_name,
# 	*
# EXCEPT (job_highlights_qualifications, job_highlights_responsibilities, job_highlights_benefits)
# FROM
# `job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# f.job_id = d.job_id
# WHERE
# salary_year < 35000-- WHERE salary_hour < 15
# ORDER BY
# salary_avg

# %%
# %%bigquery
#
# -- skill total
# SELECT
# 	COUNT(*) AS skill_count
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_skills

# %%
# %%bigquery
#
# -- skill all data nerds
# SELECT
# 	keywords.element AS skill,
# 	ROUND(COUNT(f.job_id) * 100 / (
# 	SELECT
# 		COUNT(*)
# 	FROM
# 		`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact), 1) AS skill_percent,
# 	COUNT(f.job_id) AS skill_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_skills AS s,
# 	UNNEST(keywords_all.list) AS keywords
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = s.job_id
# GROUP BY
# 	skill
# ORDER BY
# 	skill_count DESC

# %%
# %%bigquery
#
# -- skill by analyst
# SELECT
# 	keywords.element AS skill,
# 	ROUND(COUNT(f.job_id) * 100 / (
# 	SELECT
# 		COUNT(job_id)
# 	FROM
# 		`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# 	WHERE
# 		search_term = 'Data Analyst'), 1) AS skill_percent,
# 	COUNT(f.job_id) AS skill_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_skills AS s,
# 	UNNEST(keywords_all.list) AS keywords
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = s.job_id
# WHERE
# 	f.search_term = 'Data Analyst'
# GROUP BY
# 	f.search_term,
# 	skill
# ORDER BY
# 	skill_count DESC

# %%
# %%bigquery
#
# -- skill by scientist
# SELECT
# 	keywords.element AS skill,
# 	ROUND(COUNT(f.job_id) * 100 / (
# 	SELECT
# 		COUNT(job_id)
# 	FROM
# 		`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# 	WHERE
# 		search_term = 'Data Scientist'), 1) AS skill_percent,
# 	COUNT(f.job_id) AS skill_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_skills AS s,
# 	UNNEST(keywords_all.list) AS keywords
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = s.job_id
# WHERE
# 	f.search_term = 'Data Scientist'
# GROUP BY
# 	f.search_term,
# 	skill
# ORDER BY
# 	skill_count DESC

# %%
# %%bigquery
#
# -- skill by engineer
# SELECT
# 	keywords.element AS skill,
# 	ROUND(COUNT(f.job_id) * 100 / (
# 	SELECT
# 		COUNT(job_id)
# 	FROM
# 		`job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact
# 	WHERE
# 		job_title = 'Data Analyst'),1) AS skill_percent,
# 	COUNT(f.job_id) AS skill_count,
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_skills AS s,
# 	UNNEST(keywords_all.list) AS keywords
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = s.job_id
# WHERE
# 	f.job_title = 'Data Analyst'
# GROUP BY
# 	f.search_term,
# 	skill
# ORDER BY
# 	skill_count DESC

# %%
# %%bigquery
# -- salary dataframe
# SELECT
# 	search_term,
# 	salary_avg,
# 	salary_min,
# 	salary_max,
# 	salary_year,
# 	salary_hour,
# 	search_location,
# 	job_schedule_type,
# 	job_via,
# 	s.keywords_all AS job_keywords
# FROM
# 	`job-listings-366015`.gsearch_job_listings_clean.gsearch_salary AS d
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_jobs_fact AS f ON
# 	f.job_id = d.job_id
# LEFT JOIN `job-listings-366015`.gsearch_job_listings_clean.gsearch_skills AS s
#                    ON
# 	s.job_id = d.job_id
# Out:
# Query complete after 0.00s: 100%|██████████| 6/6 [00:00<00:00, 2264.74query/s]
# Downloading: 100%|██████████| 15322/15322 [00:31<00:00, 491.80rows/s]
#           search_term  salary_avg  salary_min  salary_max  salary_year  \
# 0      Data Scientist    191000.0         NaN         NaN     191000.0
# 1        Data Analyst     48982.0         NaN         NaN      48982.0
# 2      Data Scientist    108281.0         NaN         NaN     108281.0
# 3      Data Scientist    171430.0         NaN         NaN     171430.0
# 4      Data Scientist     45000.0     30000.0     60000.0      45000.0
# ...               ...         ...         ...         ...          ...
# 15317  Data Scientist    155000.0    140000.0    170000.0     155000.0
# 15318    Data Analyst    155000.0    150000.0    160000.0     155000.0
# 15319  Data Scientist    157500.0    129000.0    186000.0     157500.0
# 15320   Data Engineer    157500.0    140000.0    175000.0     157500.0
# 15321  Data Scientist    157500.0    140000.0    175000.0     157500.0
#
#        salary_hour            search_location job_schedule_type  \
# 0              NaN  California, United States         Full-time
# 1              NaN     Florida, United States         Full-time
# 2              NaN    New York, United States        Contractor
# 3              NaN                      Sudan         Full-time
# 4              NaN                  Argentina         Part-time
# ...            ...                        ...               ...
# 15317          NaN       Texas, United States         Full-time
# 15318          NaN    New York, United States         Full-time
# 15319          NaN                     Mexico         Full-time
# 15320          NaN                     Canada         Full-time
# 15321          NaN    New York, United States         Full-time
#
#                      job_via  \
# 0      via My ArkLaMiss Jobs
# 1            via Recruit.net
# 2            via Recruit.net
# 3            via Recruit.net
# 4            via Ai-Jobs.net
# ...                      ...
# 15317           via LinkedIn
# 15318           via LinkedIn
# 15319        via Ai-Jobs.net
# 15320           via EchoJobs
# 15321       via ZipRecruiter
#
#                                             job_keywords
# 0      {'list': [{'element': 'assembly'}, {'element':...
# 1                                                   None
# 2      {'list': [{'element': 'r'}, {'element': 'pytho...
# 3                      {'list': [{'element': 'python'}]}
# 4      {'list': [{'element': 'sql'}, {'element': 'exc...
# ...                                                  ...
# 15317  {'list': [{'element': 'python'}, {'element': '...
# 15318  {'list': [{'element': 'python'}, {'element': '...
# 15319  {'list': [{'element': 'sql'}, {'element': 'loo...
# 15320  {'list': [{'element': 'python'}, {'element': '...
# 15321                                               None
#
# [15322 rows x 10 columns]
